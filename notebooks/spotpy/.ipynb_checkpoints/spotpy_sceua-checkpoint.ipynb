# %% [markdown]
# # SPOTPY - calibración
# ***
# _Autor:_    __Jesús Casado__ <br> _Revisión:_ __6/12/2019__ <br>
#
# __Introducción__<br>
# Se dcalibra el modelo de nieve de la cuenca alta del Deva mediante el algoritmo de optimización SCEUA.
#
# * Los parámetros a calibrar en el modelo se definen en el  archivo _parametros.yml_.
#
# __Cosas a mejorar__ <br>
#
# __Índice__ <br>
#
# ***

# %%
import os
import numpy as np
import numpy.ma as ma
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import spotpy
from netCDF4 import Dataset
from datetime import date, datetime, timedelta
from pyproj import Proj, Transformer, CRS
from calendar import monthrange

# %%
rutaBase = os.getcwd()

# %%
# %run spotpy_setup.ipynb

# %%
os.chdir(os.path.join(rutaBase, '../'))
# %run funciones_raster.ipynb
# %run funciones_modelo_nieve.ipynb
# %run class_MODIS.ipynb
os.chdir(rutaBase)

# %% [markdown]
# ## 1. Datos
# ### 1.1 Cartografía

# %%
# ruta cartografía
rutaGIS = os.path.join(rutaBase, '../../data/GIS/')

# importar polígonos de las cuencas
cuenca = gpd.read_file(rutaGIS + "mask_465_deva.shp")

# importar mdt de la cuenca
DEM = read_ascii(rutaGIS + 'dem_465_deva.asc', crs=25830)
DEM.variable = 'elevación'
DEM.units = 'm.s.n.m'

# %% [markdown]
# ### 1.2 Nieve MODIS

# %%
# Cargar netCDF con los datos climáticos
rutaMODIS = os.path.join(rutaBase, '../../data/SnowCover/')
nc = Dataset(rutaMODIS + 'MODIS_Maximum_Snow_Extent_Terra+Aqua.nc', 'r', format='NETCDF4')

# extraer datos
data = nc['SC'][::]
units = nc['SC'].units
# fechas
times = np.array([datetime(1, 1, 1).date() + timedelta(time) for time in nc['time'][:].data])
# coordenadas
X = nc['X'][:].data
Y = nc['Y'][:].data
crs = CRS.from_epsg(nc.coordinateSystem.split(':')[1])

# guardar como objeto raster3D
SCobs = raster3D(data, X, Y, times, variable='snow cover', label='SC', units=units,
                   crs=crs)

nc.close()

# %% [markdown]
# #### Fechas de MODIS

# %%
# definir fechas de inicio y fin de los datos de MODIS
start, end = SCobs.times.min(), SCobs.times.max()
start = datetime(start.year, start.month, 1).date()
end = datetime(end.year, end.month, monthrange(end.year, end.month)[1]).date()

# %% [markdown]
# ### 1.3 Precipitación y temperatura

# %%
# Cargar netCDF con los datos climáticos
rutaClima = os.path.join(rutaBase, '../../data/clima/')
nc = Dataset(rutaClima + 'clima_1265.nc', 'r', format='NETCDF4')

# extraer variables
X = nc['X'][:].data
Y = nc['Y'][:].data
dates = nc['time'][:].data
dates = np.array([date(1979, 1, 1) + timedelta(days=int(d)) for d in dates])
pcp = nc['pcp'][::].data
tmp = nc['tmp'][::].data

nc.close()

# %%
# guardar como objetos raster3D
PCP = raster3D(pcp, X, Y, dates, units='mm', variable='Precipitación', label='P',
            crs=CRS.from_epsg(25830))

TMP = raster3D(tmp, X, Y, dates, units='°C', variable='Temperatura', label='T',
            crs=CRS.from_epsg(25830))

# %%
# enmascarar celdas sin ningún dato
PCP.enmascararNaN()
TMP.enmascararNaN()

# %% [markdown]
# ### 1.4 Radiación

# %%
rad = np.zeros((12, *DEM.data.shape)) * np.nan
for i in range(1, 7):
    asci = read_ascii(rutaClima + 'rad{0:02d}.asc'.format(i))
    radi = asci.data
    if i == 1:
        # arrays de coorenadas
        ncols, nrows, xll, yll, cs, noDATA = asci.attributes
        Xrad = np.arange(xll, xll + cs *ncols, cs)
        Yrad = np.arange(yll, yll + cs *nrows, cs)[::-1]
        # recortar filas y columnas sin dato
        radi, Xrad, Yrad = corregirRaster(radi, Xrad, Yrad)
    else:
        # recortar filas y columnas sin dato
        radi = corregirRaster(radi)
    # asignar mapa
    rad[i-1,:,:] = radi.copy()
    rad[12-i,:,:] = radi.copy()

# %%
# guardar como objeto raster3D
RAD = raster3D(rad, Xrad, Yrad, np.arange(1, 13), variable='radiación', units='-',
               label='Rad', crs=CRS.from_epsg(25830))
RAD.enmascararNaN()

# %% [markdown]
# ## 2. Calibración

# %% [markdown]
# ### 2.1 Periodos de calibración y validación

# %%
# periodo de calibración
startC = datetime(2005, 10, 1).date()
endC = datetime(2010, 9, 30).date()
# periodo de validación
startV = datetime(2010, 10, 1).date()
endV = datetime(2015, 9, 30).date()

# %%
# recortar los datos climáticos a los periodos de calibración y validación
PCPcal = PCP.extraer(startC, endC, axis=0, inplace=False)
PCPval = PCP.extraer(startV, endV, axis=0, inplace=False)
TMPcal = TMP.extraer(startC, endC, axis=0, inplace=False)
TMPval = TMP.extraer(startV, endV, axis=0, inplace=False)

# %%
# recortar datos MODIS
times = SCobs.times
i = np.where(times == endC)[0][0]
SCobsC = SCobs.extraer(times[0], times[i], axis=0, inplace=False)
SCobsV = SCobs.extraer(times[i+1], times[-1], axis=0, inplace=False)

# %% [markdown]
# ### 2.1 Lanzar calibración

# %%
# importar parámetros a calibrar
with open("parametros.yml", "r") as ymlfile:
    pars = yaml.load(ymlfile, Loader=yaml.FullLoader)
pars
# Out:
# {'Tb': {'min': -2, 'max': 6, 'ini': 0},
#  'DDF1': {'min': 0, 'max': 6, 'ini': 3},
#  'DDF2': {'min': 0, 'max': 10, 'ini': 5}}

# %%
setup = spotpy_setup(PCPcal, TMPcal, SCobsC, pars, RAD=RAD, obj_func=rendimiento_clasificacion)
sampler = spotpy.algorithms.sceua(setup, dbname='SCEUA_DDM', dbformat='csv')
#Select number of maximum repetitions
rep = 1000
sampler.sample(rep, ngs=7, kstop=3, peps=0.1, pcento=0.1)
# Out:
# Initializing the  Shuffled Complex Evolution (SCE-UA) algorithm  with  1000  repetitions
# The objective function will be minimized
# Starting burn-in sampling...
# 1 of 1000, minimal objective function=0.143327, time remaining: 00:16:41
# Initialize database...
# ['csv', 'hdf5', 'ram', 'sql', 'custom', 'noData']
# * Database file 'SCEUA_DDM.csv' created.
# 2 of 1000, minimal objective function=0.133786, time remaining: 00:28:16
# 3 of 1000, minimal objective function=0.133786, time remaining: 00:29:43
# 4 of 1000, minimal objective function=0.12683, time remaining: 00:30:30
# 5 of 1000, minimal objective function=0.125471, time remaining: 00:31:00
# 6 of 1000, minimal objective function=0.125471, time remaining: 00:31:31
# 7 of 1000, minimal objective function=0.125471, time remaining: 00:31:51
# 8 of 1000, minimal objective function=0.125471, time remaining: 00:31:58
# 9 of 1000, minimal objective function=0.125471, time remaining: 00:32:06
# 10 of 1000, minimal objective function=0.125471, time remaining: 00:32:13
# 11 of 1000, minimal objective function=0.125471, time remaining: 00:32:15
# 12 of 1000, minimal objective function=0.125471, time remaining: 00:32:16
# 13 of 1000, minimal objective function=0.125471, time remaining: 00:32:21
# 14 of 1000, minimal objective function=0.125471, time remaining: 00:32:28
# 15 of 1000, minimal objective function=0.125471, time remaining: 00:32:29
# 16 of 1000, minimal objective function=0.125471, time remaining: 00:32:30
# 17 of 1000, minimal objective function=0.125471, time remaining: 00:32:33
# 18 of 1000, minimal objective function=0.124041, time remaining: 00:32:34
# 19 of 1000, minimal objective function=0.124041, time remaining: 00:32:35
# 20 of 1000, minimal objective function=0.124041, time remaining: 00:32:34
# 21 of 1000, minimal objective function=0.124041, time remaining: 00:32:39
# 22 of 1000, minimal objective function=0.124041, time remaining: 00:32:44
# 23 of 1000, minimal objective function=0.124041, time remaining: 00:32:46
# 24 of 1000, minimal objective function=0.124041, time remaining: 00:32:47
# 25 of 1000, minimal objective function=0.124041, time remaining: 00:32:49
# 26 of 1000, minimal objective function=0.124041, time remaining: 00:32:47
# 27 of 1000, minimal objective function=0.124041, time remaining: 00:32:46
# 28 of 1000, minimal objective function=0.124041, time remaining: 00:32:46
# 29 of 1000, minimal objective function=0.124041, time remaining: 00:32:45
# 31 of 1000, minimal objective function=0.124041, time remaining: 00:32:43
# 32 of 1000, minimal objective function=0.124041, time remaining: 00:32:40
# 34 of 1000, minimal objective function=0.124041, time remaining: 00:32:34
# 36 of 1000, minimal objective function=0.124041, time remaining: 00:32:30
# 38 of 1000, minimal objective function=0.124041, time remaining: 00:32:24
# 39 of 1000, minimal objective function=0.124041, time remaining: 00:32:21
# 40 of 1000, minimal objective function=0.124041, time remaining: 00:32:19
# 41 of 1000, minimal objective function=0.124041, time remaining: 00:32:17
# 42 of 1000, minimal objective function=0.124041, time remaining: 00:32:16
# 43 of 1000, minimal objective function=0.124041, time remaining: 00:32:15
# 44 of 1000, minimal objective function=0.124041, time remaining: 00:32:16
# 46 of 1000, minimal objective function=0.122392, time remaining: 00:32:11
# 47 of 1000, minimal objective function=0.122392, time remaining: 00:32:08
# 49 of 1000, minimal objective function=0.122392, time remaining: 00:32:02
# Burn-in sampling completed...
# Starting Complex Evolution...
# ComplexEvo loop #1 in progress...
# 61 of 1000, minimal objective function=0.122392, time remaining: 00:30:33
# 66 of 1000, minimal objective function=0.122392, time remaining: 00:28:39
# 79 of 1000, minimal objective function=0.122094, time remaining: 00:27:58
# 84 of 1000, minimal objective function=0.122094, time remaining: 00:26:35
# 94 of 1000, minimal objective function=0.122077, time remaining: 00:25:58
# 99 of 1000, minimal objective function=0.122077, time remaining: 00:24:53
# 111 of 1000, minimal objective function=0.121979, time remaining: 00:24:26
# 116 of 1000, minimal objective function=0.121979, time remaining: 00:23:33
# 128 of 1000, minimal objective function=0.121979, time remaining: 00:23:15
# 133 of 1000, minimal objective function=0.121979, time remaining: 00:22:30
# 144 of 1000, minimal objective function=0.121979, time remaining: 00:22:12
# 149 of 1000, minimal objective function=0.121979, time remaining: 00:21:33
# 160 of 1000, minimal objective function=0.121979, time remaining: 00:21:18
# 165 of 1000, minimal objective function=0.121979, time remaining: 00:20:43
# ComplexEvo loop #2 in progress...
# 178 of 1000, minimal objective function=0.121953, time remaining: 00:20:35
# 182 of 1000, minimal objective function=0.121953, time remaining: 00:20:12
# 193 of 1000, minimal objective function=0.121916, time remaining: 00:19:57
# 198 of 1000, minimal objective function=0.121916, time remaining: 00:19:29
# 211 of 1000, minimal objective function=0.121916, time remaining: 00:19:19
# 215 of 1000, minimal objective function=0.121916, time remaining: 00:19:00
# 228 of 1000, minimal objective function=0.121916, time remaining: 00:18:43
# 233 of 1000, minimal objective function=0.121916, time remaining: 00:18:19
# 244 of 1000, minimal objective function=0.121916, time remaining: 00:18:06
# 249 of 1000, minimal objective function=0.121916, time remaining: 00:17:44
# 262 of 1000, minimal objective function=0.121916, time remaining: 00:17:31
# 267 of 1000, minimal objective function=0.121916, time remaining: 00:17:10
# 280 of 1000, minimal objective function=0.121916, time remaining: 00:17:01
# 285 of 1000, minimal objective function=0.121916, time remaining: 00:16:42
# ComplexEvo loop #3 in progress...
# 301 of 1000, minimal objective function=0.121916, time remaining: 00:16:33
# 306 of 1000, minimal objective function=0.121916, time remaining: 00:16:15
# 319 of 1000, minimal objective function=0.121916, time remaining: 00:16:01
# 324 of 1000, minimal objective function=0.121916, time remaining: 00:15:43
# 338 of 1000, minimal objective function=0.121916, time remaining: 00:15:29
# 343 of 1000, minimal objective function=0.121916, time remaining: 00:15:13
# 355 of 1000, minimal objective function=0.121916, time remaining: 00:15:00
# 360 of 1000, minimal objective function=0.121916, time remaining: 00:14:44
# 374 of 1000, minimal objective function=0.121916, time remaining: 00:14:29
# 379 of 1000, minimal objective function=0.121916, time remaining: 00:14:14
# 392 of 1000, minimal objective function=0.121916, time remaining: 00:13:59
# 397 of 1000, minimal objective function=0.121916, time remaining: 00:13:45
# 410 of 1000, minimal objective function=0.121916, time remaining: 00:13:31
# 415 of 1000, minimal objective function=0.121916, time remaining: 00:13:18
# Objective function convergence criteria is now being updated and assessed...
# Updated convergence criteria: 0.052309
# THE BEST POINT HAS IMPROVED IN LAST 3 LOOPS BY LESS THAN THE USER-SPECIFIED THRESHOLD 0.100000
# CONVERGENCY HAS ACHIEVED BASED ON OBJECTIVE FUNCTION CRITERIA!!!
# SEARCH WAS STOPPED AT TRIAL NUMBER: 416
# NUMBER OF DISCARDED TRIALS: 0
# NORMALIZED GEOMETRIC RANGE = 0.785345
# THE BEST POINT HAS IMPROVED IN LAST 3 LOOPS BY 0.052309 PERCENT
#
# *** Final SPOTPY summary ***
# Total Duration: 568.99 seconds
# Total Repetitions: 416
# Minimal objective value: 0.121916
# Corresponding parameter setting:
# Tb: 4.80258
# DDF1: 4.71342
# DDF2: 8.81763
# ******************************

# %% [markdown]
# ### 2.2 Resultados de la calibración

# %%
rutaOut = os.path.join(rutaBase, '../../output/')

# %%
# importar resultados
sceua = pd.read_csv('SCEUA_DDM.csv', usecols=range(4))
sceua.columns = ['f1'] + [col[3:] for col in sceua.columns[1:]]
sceua.shape
# Out:
# (196, 4)

# %% [markdown]
# No entiendo por qué a pesar de definir 1000 iteraciones, en el archivo de salida de la calibración sólo se guardan 196.

# %%
# extraer mejor rendimiento y sus parámetros asociados
best_idx = sceua.f1.idxmin()
best_pars = sceua.loc[best_idx].iloc[1:]
best_OF = sceua.f1.min()
print('f1 = {0:.3f}'.format(best_OF))
for par in best_pars.index:
    print('{0} = {1:.3f}'.format(par, best_pars[par]), end='\t')
# Out:
# f1 = 0.122
# Tb = 4.800	DDF1 = 4.715	DDF2 = 8.820

# %%
sceua.head()
# Out:
#        f1      Tb     DDF1   DDF2
# 0  0.1433 -1.9670  0.05423  8.740
# 1  0.1338 -0.7440  0.84800  5.582
# 2  0.1342 -0.5728  3.66400  5.117
# 3  0.1268  2.3340  5.96000  5.100
# 4  0.1255  2.1500  2.95500  4.906

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(16, 5), sharey=True)

for ax, par in zip(axes.flatten(), pars):
    ax.scatter(sceua[par], 1 - sceua.f1, s=5, label='iters')
    ax.scatter(best_pars[par], 1 - best_OF, c='orange', s=15, label='best')
    ax.set_xlim(pars[par]['min'], pars[par]['max'])
    ax.set_title(par, fontsize=13)

handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc=8, ncol=2, fontsize=13);

plt.savefig(rutaOut + 'Sensibilidad parámetros.png', dpi=600, bbox_inches='tight');

# %%
# gráficos de la evolución de la calibración
fig, axes = plt.subplots(nrows=4, figsize=(16, 16))

axes[0].plot(1 - sceua.f1, c='k', lw=1)
axes[0].scatter(best_idx, 1 - best_OF, marker='+', color='maroon')
axes[0].set(ylabel='f1', ylim=(0.8, 1))
for ax,  par in zip(axes[1:], pars):
    ax.plot(sceua[par], lw=1)
    ax.scatter(best_idx, sceua.loc[best_idx, par], marker='+', color='maroon')
    ax.set(ylabel=par, ylim=(pars[par]['min'], pars[par]['max']))

    plt.savefig(rutaOut + 'Evolución calibración.png', dpi=600, bbox_inches='tight');

# %% [markdown]
# ## 3 Simulación

# %%
# calcular modelo de nieve
SWE, SM = degreeDayMethod(PCPval, TMPval, RAD=RAD, Ts=0., Tb=best_pars['Tb'],
                                DDF1=best_pars['DDF1'], DDF2=best_pars['DDF2'],
                                verbose=True)

# reclasificar SWE en un mapa binario
SCsim = snowCover(SWE, threshold=1)

# agregar simulación a paso 8 días
SCsim8 = remuestrearMODIS(SCobsV, SCsim, func='max')
SWEsim8 = remuestrearMODIS(SCobsV, SWE, func='max')
# Out:
# Paso 1826 de 1826:	2015-09-30

# %%
fig, ax = plt.subplots(nrows=4, figsize=(16, 14), sharex=True, sharey=False)

# serie de equivalente agua-nieve
serieSWE = pd.Series(np.nanmean(SWE.data, axis=(1,2)), index=SWE.times)
ax[0].plot(serieSWE, lw=1)
ax[0].set_ylabel('SWE (mm)')

# serie de fusión
serieSM = pd.Series(np.nanmean(SM.data, axis=(1,2)), index=SM.times)
ax[1].plot(serieSM, lw=1)
ax[1].set_ylabel('SM (mm)')

# series de nº de celdas nevadas
cellsObs = pd.Series(np.nansum(SCobsV.data, axis=(1, 2)).data, index=SCobsV.times)
cellsSim = pd.Series(np.nansum(SCsim8.data, axis=(1, 2)).data, index=SCsim8.times)
ax[2].plot(cellsObs, ls='--', c='k', lw=1, label='obs')
ax[2].plot(cellsSim, lw=1, label='sim')
ax[2].set_ylabel('n. cells with snow')
ax[2].legend();

# serie de rendimiento en f1
f1Serie = rendimiento_clasificacion(SCobsV, SCsim8, score='f1')
f1Mean = f1Serie.mean()
ax[3].plot(f1Serie, lw=1)
ax[3].set(ylabel='f1 (-)', ylim=(0, 1))
ax[3].text(0.9, 0.075, 'f1 = {0:.3f}'.format(f1Mean), fontsize=13, transform=ax[3].transAxes);

plt.savefig(rutaOut + 'Resultados_validación.png', dpi=600, bbox_inches='tight');

# %%
# serie de resultados
serieSWE = pd.Series(np.nanmean(SWE.data, axis=(1,2)), index=SWE.times)
serieSM = pd.Series(np.nanmean(SM.data, axis=(1,2)), index=SM.times)

fig, axes = plt.subplots(nrows=3, figsize=(16, 12), sharex=True, sharey=False)
# series simuladas: snow-water equivalent, snowmelt
for ax, serie, label in zip(axes[:2], [serieSWE, serieSM], ['SWE', 'SM']):
    ax.plot(serie)
    ax.set_ylabel(label + ' (mm)')
# serie de rendimiento
axes[2].plot(f1Serie)
axes[2].set(ylabel='f1 (-)', ylim=(0, 1))
axes[2].text(0.9, 0.075, 'f1 = {0:.3f}'.format(f1Mean), fontsize=13, transform=axes[2].transAxes);
plt.savefig(rutaOut + 'Resultados_validación.png', dpi=600, bbox_inches='tight');

# %%
# definir colores
colors = np.array([[255, 255, 255 , 0], [33, 178, 171, 130]])
colors = colors / 255.
cmap_snow = ListedColormap(colors)
boundaries = [0, .5, 1]
norm = BoundaryNorm(boundaries, cmap_snow.N, clip=True)
snow_patch = mpatches.Patch(color=cmap_snow.colors[1], label='snow')

# %%
# definir límites del mapa
xmin, ymin, xmax, ymax = cuenca.bounds.values[0]
xmin -= DEM.cellsize * 2
ymin -= DEM.cellsize * 2
xmax += DEM.cellsize * 2
ymax += DEM.cellsize * 2
extent = [xmin, xmax, ymin, ymax]

# %%
t = 12
time = SCobsV.times[t]
print(time)
fig, axes = plt.subplots(ncols=3, figsize=(15, 5))

SCobsV.variable = 'observed snow cover'
for i, (ax, Var) in enumerate(zip(axes, [SWEsim8, SCsim8, SCobsV])):
    ax.imshow(DEM.data, extent=DEM.extent, cmap='pink')
    if i == 0:
        ax.imshow(Var.data[t,:,:], extent=Var.extent(), cmap='summer_r', alpha=.5)
    else:
        ax.imshow(Var.data[t,:,:], extent=Var.extent(), cmap=cmap_snow, norm=norm)
    ax.set_title(Var.variable)
    ax.axis('off')
fig.text(0.5, 0.9, time, horizontalalignment='center', fontsize=13)
fig.text(0.5, .1, 'f1 = {0:.3f}'.format(f1Serie[time]), horizontalalignment='center', fontsize=13)
fig.legend(handles=[snow_patch], loc=8, fontsize=13);
plt.savefig(rutaOut + 'Mapas_validación.png', dpi=600, bbox_inches='tight');
# Out:
# 2011-01-09

# %%
SCsim8.data.shape, SCsim8.times.shape
# Out:
# ((230, 46, 47), (230,))

# %%
SCobsV.data.shape, SCobsV.times.shape
# Out:
# ((230, 46, 47), (230,))

# %%
np.all(SCsim8.times == SCobsV.times )
# Out:
# True

# %%
video(SCsim8, cuenca, cmap_snow, norm, DEM, figsize=(6, 6))
# Out:
# <video width="432" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
video(SCobsV, cuenca, cmap_snow, norm, DEM, figsize=(6, 6))
# Out:
# <video width="432" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# vídeo simulado vs observado
mp4File = rutaOut + 'SC_simulado_vs_observado_(calib).mp4'
video2(SCobsV, SCsim8, cuenca, cmap_snow, norm, DEM, fps=3, dpi=300, figsize=(12, 6),
       extent=extent, labels=['simulado', 'observado'], export=mp4File)
# Out:
# Exportando archivo C:\Users\jcr693\Documents\GitHub\Calibrar\notebooks\spotpy\../../output/SC_simulado_vs_observado_(calib).mp4
